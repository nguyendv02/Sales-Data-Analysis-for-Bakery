# %%
# !pip install apyori

# %%
import numpy as np
import pandas as pd

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from apyori import apriori

# %% [markdown]
# # **1. Pre-process data**

# %%
df_bakery = pd.read_csv('./Bakery.csv')
df_bakery.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend

# %%
# Processing datetime

dateTime =pd.to_datetime(df_bakery['DateTime'])
df_bakery['Day'] = dateTime.dt.day_name()
df_bakery['Month'] = dateTime.dt.month_name()
df_bakery['Year'] = dateTime.dt.year
df_bakery.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType  \
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend
#
#       Day    Month  Year
# 0  Sunday  October  2016
# 1  Sunday  October  2016
# 2  Sunday  October  2016
# 3  Sunday  October  2016
# 4  Sunday  October  2016

# %% [markdown]
# # **2. Data Exploration**

# %%
def Plot_Freq_barchart(df, column, top):
  freq = df[column].value_counts()

  fig = px.bar(freq.head(top),
              color = freq.head(top),
              color_continuous_scale = px.colors.sequential.Mint,
              title=f'Bar Chart of {column}')

  fig.update_traces(width=0.3)
  fig.update_layout(width=600)
  fig.show()

def Plot_Pie_barchart(df, column):

    counts = df[column].value_counts()

    fig = px.pie(names=counts.index,
                 values=counts.values,
                 color_discrete_sequence=px.colors.sequential.Sunset,
                 title=f'Pie Chart of {column}')

    fig.update_layout(width=600)
    fig.show()

# %%
Plot_Freq_barchart(df_bakery, 'Items', 15)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0a2c6601-a9cc-4768-83f1-71ae662fa83f" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0a2c6601-a9cc-4768-83f1-71ae662fa83f")) {                    Plotly.newPlot(                        "0a2c6601-a9cc-4768-83f1-71ae662fa83f",                        [{"alignmentgroup":"True","hovertemplate":"Items=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[5471,3325,1435,1025,856,771,616,590,540,379,374,370,369,369,342],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Coffee","Bread","Tea","Cake","Pastry","Sandwich","Medialuna","Hot chocolate","Cookies","Brownie","Farm House","Muffin","Alfajores","Juice","Soup"],"xaxis":"x","y":[5471,3325,1435,1025,856,771,616,590,540,379,374,370,369,369,342],"yaxis":"y","type":"bar","width":0.3}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0, ...

# %%
Plot_Freq_barchart(df_bakery, 'Day', 7)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a7c86ec-5f81-4564-909d-77962192f052" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a7c86ec-5f81-4564-909d-77962192f052")) {                    Plotly.newPlot(                        "6a7c86ec-5f81-4564-909d-77962192f052",                        [{"alignmentgroup":"True","hovertemplate":"Day=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3554,3266,3118,3035,2645,2601,2288],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Saturday","Friday","Sunday","Monday","Tuesday","Thursday","Wednesday"],"xaxis":"x","y":[3554,3266,3118,3035,2645,2601,2288],"yaxis":"y","type":"bar","width":0.3}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pat ...

# %%
Plot_Freq_barchart(df_bakery, 'Month', 12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bf8ca42e-e4f5-4dd1-97b8-e1d0e4b10a65" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf8ca42e-e4f5-4dd1-97b8-e1d0e4b10a65")) {                    Plotly.newPlot(                        "bf8ca42e-e4f5-4dd1-97b8-e1d0e4b10a65",                        [{"alignmentgroup":"True","hovertemplate":"Month=%{x}\u003cbr\u003evalue=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3220,3076,3027,2748,2647,1048,1041,924,741,739,700,596],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["March","November","January","February","December","April","October","May","July","June","August","September"],"xaxis":"x","y":[3220,3076,3027,2748,2647,1048,1041,924,741,739,700,596],"yaxis":"y","type":"bar","width":0.3}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"e ...

# %%
Plot_Pie_barchart(df_bakery, 'Daypart')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="300cf3b8-d2c1-48c9-959e-ebc4d2f171ba" class="plotly-graph-div" style="height:525px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("300cf3b8-d2c1-48c9-959e-ebc4d2f171ba")) {                    Plotly.newPlot(                        "300cf3b8-d2c1-48c9-959e-ebc4d2f171ba",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Afternoon","Morning","Evening","Night"],"legendgroup":"","name":"","showlegend":true,"values":[11569,8404,520,14],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# # **3. Insights from Data**

# %%
def Tranform_Transaction(df_bakery):

  transaction = []

  for trans_no in df_bakery['TransactionNo'].unique():
    list_item_of_trans = df_bakery[df_bakery['TransactionNo']==trans_no]['Items'].tolist()
    transaction.append(tuple(list_item_of_trans))

  return transaction

# %%
def print_rules(rules, top_n):
    print(f"Top {top_n} rules with highest support:")

    sorted_by_support = sorted(rules, key=lambda x: x.support, reverse=True)

    for i in range(min(top_n, len(sorted_by_support))):
        # Extract information from the RelationRecord object
        rule = sorted_by_support[i]
        items = list(rule.items)
        support = rule.support

        # Loop through all ordered statistics (for rules with multiple antecedents)
        for os in rule.ordered_statistics:
            antecedent = list(os.items_base)
            consequent = list(os.items_add)
            confidence = os.confidence
            lift = os.lift

            print(f"Items: {items}")
            print(f"Support: {support:.3f}")
            print(f"  Rule: {antecedent} -> {consequent}")
            print(f"  Confidence: {confidence:.3f}")
            print(f"  Lift: {lift:.3f}")
            print()
            print('-----------------')
            print()

# %%
transaction = Tranform_Transaction(df_bakery)
# Generate rule based on Apriori algorithm
rules = list(apriori(transaction, min_support = 0.01, min_confidence = 0.05))
filtered_rules = [rule for rule in rules if len(rule.items) >= 2]

# %%
print_rules(filtered_rules, 10)
# Out:
# Top 10 rules with highest support:
# Items: ['Bread', 'Coffee']
# Support: 0.090
#   Rule: [] -> ['Bread', 'Coffee']
#   Confidence: 0.090
#   Lift: 1.000
#
# -----------------
#
# Items: ['Bread', 'Coffee']
# Support: 0.090
#   Rule: ['Bread'] -> ['Coffee']
#   Confidence: 0.275
#   Lift: 0.575
#
# -----------------
#
# Items: ['Bread', 'Coffee']
# Support: 0.090
#   Rule: ['Coffee'] -> ['Bread']
#   Confidence: 0.188
#   Lift: 0.575
#
# -----------------
#
# Items: ['Cake', 'Coffee']
# Support: 0.055
#   Rule: [] -> ['Cake', 'Coffee']
#   Confidence: 0.055
#   Lift: 1.000
#
# -----------------
#
# Items: ['Cake', 'Coffee']
# Support: 0.055
#   Rule: ['Cake'] -> ['Coffee']
#   Confidence: 0.527
#   Lift: 1.102
#
# -----------------
#
# Items: ['Cake', 'Coffee']
# Support: 0.055
#   Rule: ['Coffee'] -> ['Cake']
#   Confidence: 0.114
#   Lift: 1.102
#
# -----------------
#
# Items: ['Tea', 'Coffee']
# Support: 0.050
#   Rule: ['Coffee'] -> ['Tea']
#   Confidence: 0.104
#   Lift: 0.731
#
# -----------------
#
# Items: ['Tea', 'Coffee']
# Support: 0.050
#   Rule: ['Tea'] -> ['Coffee']
#   Confidence: 0.350
#   Lift: 0.731
#
# -----------------
#
# Items: ['Pastry', 'Coffee']
# Support: 0.048
#   Rule: ['Coffee'] -> ['Pastry']
#   Confidence: 0.099
#   Lift: 1.154
#
# -----------------
#
# Items: ['Pastry', 'Coffee']
# Support: 0.048
#   Rule: ['Pastry'] -> ['Coffee']
#   Confidence: 0.552
#   Lift: 1.154
#
# -----------------
#
# Items: ['Sandwich', 'Coffee']
# Support: 0.038
#   Rule: ['Coffee'] -> ['Sandwich']
#   Confidence: 0.080
#   Lift: 1.113
#
# -----------------
#
# Items: ['Sandwich', 'Coffee']
# Support: 0.038
#   Rule: ['Sandwich'] -> ['Coffee']
#   Confidence: 0.532
#   Lift: 1.113
#
# -----------------
#
# Items: ['Medialuna', 'Coffee']
# Support: 0.035
#   Rule: ['Coffee'] -> ['Medialuna']
#   Confidence: 0.074
#   Lift: 1.190
#
# -----------------
#
# Items: ['Medialuna', 'Coffee']
# Support: 0.035
#   Rule: ['Medialuna'] -> ['Coffee']
#   Confidence: 0.569
#   Lift: 1.190
#
# -----------------
#
# Items: ['Hot chocolate', 'Coffee']
# Support: 0.030
#   Rule: ['Coffee'] -> ['Hot chocolate']
#   Confidence: 0.062
#   Lift: 1.060
#
# -----------------
#
# Items: ['Hot chocolate', 'Coffee']
# Support: 0.030
#   Rule: ['Hot chocolate'] -> ['Coffee']
#   Confidence: 0.507
#   Lift: 1.060
#
# -----------------
#
# Items: ['Bread', 'Pastry']
# Support: 0.029
#   Rule: ['Bread'] -> ['Pastry']
#   Confidence: 0.089
#   Lift: 1.035
#
# -----------------
#
# Items: ['Bread', 'Pastry']
# Support: 0.029
#   Rule: ['Pastry'] -> ['Bread']
#   Confidence: 0.339
#   Lift: 1.035
#
# -----------------
#
# Items: ['Cookies', 'Coffee']
# Support: 0.028
#   Rule: ['Coffee'] -> ['Cookies']
#   Confidence: 0.059
#   Lift: 1.084
#
# -----------------
#
# Items: ['Cookies', 'Coffee']
# Support: 0.028
#   Rule: ['Cookies'] -> ['Coffee']
#   Confidence: 0.518
#   Lift: 1.084
#
# -----------------
#
# Items: ['Tea', 'Bread']
# Support: 0.028
#   Rule: ['Bread'] -> ['Tea']
#   Confidence: 0.086
#   Lift: 0.602
#
# -----------------
#
# Items: ['Tea', 'Bread']
# Support: 0.028
#   Rule: ['Tea'] -> ['Bread']
#   Confidence: 0.197
#   Lift: 0.602
#
# -----------------

# %%
for rule in filtered_rules:
  print(rule)
# Out:
# RelationRecord(items=frozenset({'Alfajores', 'Bread'}), support=0.01035393555203381, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Bread'}), confidence=0.28488372093023256, lift=0.8706568997754768)])
# RelationRecord(items=frozenset({'Alfajores', 'Coffee'}), support=0.0196513470681458, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Alfajores'}), items_add=frozenset({'Coffee'}), confidence=0.5406976744186046, lift=1.1302348693401265)])
# RelationRecord(items=frozenset({'Bread', 'Brownie'}), support=0.010776545166402536, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brownie'}), items_add=frozenset({'Bread'}), confidence=0.2691292875989446, lift=0.8225084621001004)])
# RelationRecord(items=frozenset({'Bread', 'Cake'}), support=0.02334918119387216, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Cake'}), confidence=0.07135938004520505, lift=0.6870971842602908), OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Bread'}), confidence=0.22482197355035605, lift=0.6870971842602906)])
# RelationRecord(items=frozenset({'Bread', 'Coffee'}), support=0.09001584786053883, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Bread', 'Coffee'}), confidence=0.09001584786053883, lift=1.0), OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Coffee'}), confidence=0.2751049402647724, lift=0.5750592446126481), OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Bread'}), confidence=0.1881625441696113, lift=0.5750592446126481)])
# RelationRecord(items=frozenset({'Cookies', 'Bread'}), support=0.014474379292128896, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Bread'}), confidence=0.26601941747572816, lift=0.813004128643128)])
# RelationRecord(items=frozenset({'Bread', 'Hot chocolate'}), support=0.01341785525620708, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Bread'}), confidence=0.23007246376811594, lift=0.7031436453229634)])
# RelationRecord(items=frozenset({'Bread', 'Medialuna'}), support=0.016904384574749076, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Medialuna'}), confidence=0.051662899580238945, lift=0.8358792214136096), OrderedStatistic(items_base=frozenset({'Medialuna'}), items_add=frozenset({'Bread'}), confidence=0.27350427350427353, lift=0.8358792214136097)])
# RelationRecord(items=frozenset({'Bread', 'Pastry'}), support=0.029160063391442156, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Pastry'}), confidence=0.08911850177591218, lift=1.034977447004919), OrderedStatistic(items_base=frozenset({'Pastry'}), items_add=frozenset({'Bread'}), confidence=0.33865030674846625, lift=1.0349774470049187)])
# RelationRecord(items=frozenset({'Sandwich', 'Bread'}), support=0.017010036978341258, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Sandwich'}), confidence=0.05198579270261544, lift=0.7235963646033163), OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Bread'}), confidence=0.23676470588235293, lift=0.7235963646033163)])
# RelationRecord(items=frozenset({'Tea', 'Bread'}), support=0.02810353935552034, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Bread'}), items_add=frozenset({'Tea'}), confidence=0.08588957055214724, lift=0.6021813224267212), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Bread'}), confidence=0.19703703703703704, lift=0.6021813224267213)])
# RelationRecord(items=frozenset({'Brownie', 'Coffee'}), support=0.0196513470681458, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Brownie'}), items_add=frozenset({'Coffee'}), confidence=0.4907651715039578, lift=1.025859617554099)])
# RelationRecord(items=frozenset({'Cake', 'Coffee'}), support=0.054727945060750134, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'Cake', 'Coffee'}), confidence=0.054727945060750134, lift=1.0), OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Coffee'}), confidence=0.5269582909460835, lift=1.1015150670946732), OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Cake'}), confidence=0.11439929328621908, lift=1.101515067094673)])
# RelationRecord(items=frozenset({'Cake', 'Hot chocolate'}), support=0.011410459587955626, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Hot chocolate'}), confidence=0.1098677517802645, lift=1.883873678623557), OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Cake'}), confidence=0.1956521739130435, lift=1.883873678623557)])
# RelationRecord(items=frozenset({'Tea', 'Cake'}), support=0.02377179080824089, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Tea'}), confidence=0.2288911495422177, lift=1.6047812817904374), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Cake'}), confidence=0.16666666666666669, lift=1.6047812817904377)])
# RelationRecord(items=frozenset({'Cookies', 'Coffee'}), support=0.02820919175911252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Cookies'}), confidence=0.05896643109540636, lift=1.083722854986449), OrderedStatistic(items_base=frozenset({'Cookies'}), items_add=frozenset({'Coffee'}), confidence=0.5184466019417476, lift=1.083722854986449)])
# RelationRecord(items=frozenset({'Hot chocolate', 'Coffee'}), support=0.029582673005810883, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Hot chocolate'}), confidence=0.061837455830388695, lift=1.0603107236134584), OrderedStatistic(items_base=frozenset({'Hot chocolate'}), items_add=frozenset({'Coffee'}), confidence=0.5072463768115942, lift=1.0603107236134584)])
# RelationRecord(items=frozenset({'Juice', 'Coffee'}), support=0.020602218700475437, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Juice'}), items_add=frozenset({'Coffee'}), confidence=0.5342465753424658, lift=1.11674996369621)])
# RelationRecord(items=frozenset({'Medialuna', 'Coffee'}), support=0.03518225039619651, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Medialuna'}), confidence=0.07354240282685512, lift=1.1898783636857841), OrderedStatistic(items_base=frozenset({'Medialuna'}), items_add=frozenset({'Coffee'}), confidence=0.5692307692307692, lift=1.1898783636857841)])
# RelationRecord(items=frozenset({'Muffin', 'Coffee'}), support=0.018806127839408347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Muffin'}), items_add=frozenset({'Coffee'}), confidence=0.489010989010989, lift=1.0221928027802585)])
# RelationRecord(items=frozenset({'Pastry', 'Coffee'}), support=0.04754358161648178, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Pastry'}), confidence=0.09938162544169611, lift=1.154168202215526), OrderedStatistic(items_base=frozenset({'Pastry'}), items_add=frozenset({'Coffee'}), confidence=0.5521472392638037, lift=1.154168202215526)])
# RelationRecord(items=frozenset({'Sandwich', 'Coffee'}), support=0.038246170100369785, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Sandwich'}), confidence=0.0799469964664311, lift=1.1127916493452503), OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Coffee'}), confidence=0.5323529411764706, lift=1.1127916493452503)])
# RelationRecord(items=frozenset({'Scone', 'Coffee'}), support=0.018066561014263075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Scone'}), items_add=frozenset({'Coffee'}), confidence=0.5229357798165138, lift=1.0931067040554998)])
# RelationRecord(items=frozenset({'Soup', 'Coffee'}), support=0.01584786053882726, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Soup'}), items_add=frozenset({'Coffee'}), confidence=0.4601226993865031, lift=0.961806835179605)])
# RelationRecord(items=frozenset({'Spanish Brunch', 'Coffee'}), support=0.010882197569994718, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Spanish Brunch'}), items_add=frozenset({'Coffee'}), confidence=0.5988372093023255, lift=1.2517655004519679)])
# RelationRecord(items=frozenset({'Tea', 'Coffee'}), support=0.049867934495509775, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coffee'}), items_add=frozenset({'Tea'}), confidence=0.10424028268551237, lift=0.730840204161759), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Coffee'}), confidence=0.3496296296296296, lift=0.7308402041617589)])
# RelationRecord(items=frozenset({'Toast', 'Coffee'}), support=0.023666138404648707, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Toast'}), items_add=frozenset({'Coffee'}), confidence=0.7044025157232704, lift=1.4724314954330286)])
# RelationRecord(items=frozenset({'Tea', 'Sandwich'}), support=0.014368726888536715, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Sandwich'}), items_add=frozenset({'Tea'}), confidence=0.2, lift=1.4022222222222223), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Sandwich'}), confidence=0.10074074074074074, lift=1.4022222222222223)])
# RelationRecord(items=frozenset({'Bread', 'Cake', 'Coffee'}), support=0.010036978341257264, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Bread', 'Coffee'}), confidence=0.09664292980671414, lift=1.0736212800710674), OrderedStatistic(items_base=frozenset({'Bread', 'Cake'}), items_add=frozenset({'Coffee'}), confidence=0.4298642533936652, lift=0.8985567929264666), OrderedStatistic(items_base=frozenset({'Bread', 'Coffee'}), items_add=frozenset({'Cake'}), confidence=0.11150234741784038, lift=1.0736212800710674), OrderedStatistic(items_base=frozenset({'Cake', 'Coffee'}), items_add=frozenset({'Bread'}), confidence=0.1833976833976834, lift=0.5604969562024777)])
# RelationRecord(items=frozenset({'Bread', 'Pastry', 'Coffee'}), support=0.011199154780771263, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Pastry'}), items_add=frozenset({'Bread', 'Coffee'}), confidence=0.13006134969325153, lift=1.4448716840922837), OrderedStatistic(items_base=frozenset({'Bread', 'Coffee'}), items_add=frozenset({'Pastry'}), confidence=0.12441314553990611, lift=1.4448716840922837), OrderedStatistic(items_base=frozenset({'Bread', 'Pastry'}), items_add=frozenset({'Coffee'}), confidence=0.38405797101449274, lift=0.802806690735904), OrderedStatistic(items_base=frozenset({'Pastry', 'Coffee'}), items_add=frozenset({'Bread'}), confidence=0.23555555555555555, lift=0.7199009794424712)])
# RelationRecord(items=frozenset({'Tea', 'Cake', 'Coffee'}), support=0.010036978341257264, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Cake'}), items_add=frozenset({'Tea', 'Coffee'}), confidence=0.09664292980671414, lift=1.9379773953825197), OrderedStatistic(items_base=frozenset({'Tea'}), items_add=frozenset({'Cake', 'Coffee'}), confidence=0.07037037037037037, lift=1.285821535821536), OrderedStatistic(items_base=frozenset({'Cake', 'Coffee'}), items_add=frozenset({'Tea'}), confidence=0.1833976833976834, lift=1.2858215358215357), OrderedStatistic(items_base=frozenset({'Tea', 'Cake'}), items_add=frozenset({'Coffee'}), confidence=0.4222222222222222, lift=0.8825824499411071), OrderedStatistic(items_base=frozenset({'Tea', 'Coffee'}), items_add=frozenset({'Cake'}), confidence=0.20127118644067796, lift=1.9379773953825197)])
